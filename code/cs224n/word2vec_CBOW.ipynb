# %%
# 导入一些需要的库
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf
# Out:
# d:\devsoft\conda\envs\env_nlp\lib\site-packages\OpenSSL\_util.py:6: CryptographyDeprecationWarning: Python 3.5 support will be dropped in the next release of cryptography. Please upgrade your Python.
#   from cryptography.hazmat.bindings.openssl.binding import Binding
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-8cdc0dde5665> in <module>
#      13 from six.moves import urllib
#      14 from six.moves import xrange  # pylint: disable=redefined-builtin
# ---> 15 import tensorflow as tf
#
# d:\devsoft\conda\envs\env_nlp\lib\site-packages\tensorflow\__init__.py in <module>
#      22
#      23 # pylint: disable=wildcard-import
# ---> 24 from tensorflow.python import *
#      25 # pylint: enable=wildcard-import
#      26
#
# d:\devsoft\conda\envs\env_nlp\lib\site-packages\tensorflow\python\__init__.py in <module>
#      79 # Bring in subpackages.
#      80 from tensorflow.python import data
# ---> 81 from tensorflow.python import keras
#      82 from tensorflow.python.estimator import estimator_lib as estimator
#      83 from tensorflow.python.feature_column import feature_column_lib as feature_column
#
# d:\devsoft\conda\envs\env_nlp\lib\site-packages\tensorflow\python\keras\__init__.py in <module>
#      24
#      25 # pylint: disable=wildcard-import
# ---> 26 from tensorflow.python.keras import activations
#      27 from tensorflow.python.keras import applications
#      28 from tensorflow.python.keras import backend
#
# d:\devsoft\conda\envs\env_nlp\lib\site-packages\tensorflow\python\keras\activations\__init__.py in <module>
#      20
#      21 # Activation functions.
# ---> 22 from tensorflow.python.keras._impl.keras.activations import elu
#      23 from tensorflow.python.keras._impl.keras.activations import hard_sigmoid
#      24 from tensorflow.python.keras._impl.keras.activations import linear
#
# d:\devsoft\conda\envs\env_nlp\lib\site-packages\tensorflow\python\keras\_impl\keras\__init__.py in <module>
#      19 from __future__ import print_function
#      20
# ---> 21 from tensorflow.python.keras._impl.keras import activations
#      22 from tensorflow.python.keras._impl.keras import applications
#      23 from tensorflow.python.keras._impl.keras import backend
#
# d:\devsoft\conda\envs\env_nlp\lib\site-packages\tensorflow\python\keras\_impl\keras\activations.py in <module>
#      22
#      23 from tensorflow.python.keras._impl.keras import backend as K
# ---> 24 from tensorflow.python.keras._impl.keras.utils.generic_utils import deserialize_keras_object
#      25 from tensorflow.python.layers.base import Layer
#      26 from tensorflow.python.platform import tf_logging as logging
#
# d:\devsoft\conda\envs\env_nlp\lib\site-packages\tensorflow\python\keras\_impl\keras\utils\__init__.py in <module>
#      34 from tensorflow.python.keras._impl.keras.utils.np_utils import normalize
#      35 from tensorflow.python.keras._impl.keras.utils.np_utils import to_categorical
# ---> 36 from tensorflow.python.keras._impl.keras.utils.training_utils import multi_gpu_model
#      37 from tensorflow.python.keras._impl.keras.utils.vis_utils import plot_model
#      38
#
# d:\devsoft\conda\envs\env_nlp\lib\site-packages\tensorflow\python\keras\_impl\keras\utils\training_utils.py in <module>
#      20 from tensorflow.python.framework import ops
#      21 from tensorflow.python.keras._impl.keras import backend as K
# ---> 22 from tensorflow.python.keras._impl.keras.engine.training import Model
#      23 from tensorflow.python.ops import array_ops
#      24 from tensorflow.python.util.tf_export import tf_export
#
# d:\devsoft\conda\envs\env_nlp\lib\site-packages\tensorflow\python\keras\_impl\keras\engine\__init__.py in <module>
#      24 from tensorflow.python.keras._impl.keras.engine.topology import InputSpec
#      25 from tensorflow.python.keras._impl.keras.engine.topology import Layer
# ---> 26 from tensorflow.python.keras._impl.keras.engine.training import Model
#      27
#      28
#
# d:\devsoft\conda\envs\env_nlp\lib\site-packages\tensorflow\python\keras\_impl\keras\engine\training.py in <module>
#      26 from tensorflow.python.framework import ops
#      27 from tensorflow.python.keras._impl.keras import backend as K
# ---> 28 from tensorflow.python.keras._impl.keras import callbacks as cbks
#      29 from tensorflow.python.keras._impl.keras import losses
#      30 from tensorflow.python.keras._impl.keras import metrics as metrics_module
#
# d:\devsoft\conda\envs\env_nlp\lib\site-packages\tensorflow\python\keras\_impl\keras\callbacks.py in <module>
#      39
#      40 try:
# ---> 41   import requests
#      42 except ImportError:
#      43   requests = None
#
# d:\devsoft\conda\envs\env_nlp\lib\site-packages\requests\__init__.py in <module>
#      50 # Attempt to enable urllib3's SNI support, if possible
#      51 try:
# ---> 52     from .packages.urllib3.contrib import pyopenssl
#      53     pyopenssl.inject_into_urllib3()
#      54 except ImportError:
#
# d:\devsoft\conda\envs\env_nlp\lib\site-packages\requests\packages\urllib3\contrib\pyopenssl.py in <module>
#      44 from __future__ import absolute_import
#      45
# ---> 46 import OpenSSL.SSL
#      47 from cryptography import x509
#      48 from cryptography.hazmat.backends.openssl import backend as openssl_backend
#
# d:\devsoft\conda\envs\env_nlp\lib\site-packages\OpenSSL\__init__.py in <module>
#       6 """
#       7
# ----> 8 from OpenSSL import rand, crypto, SSL
#       9 from OpenSSL.version import __version__
#      10
#
# d:\devsoft\conda\envs\env_nlp\lib\site-packages\OpenSSL\SSL.py in <module>
#     116 SSL_ST_ACCEPT = _lib.SSL_ST_ACCEPT
#     117 SSL_ST_MASK = _lib.SSL_ST_MASK
# --> 118 SSL_ST_INIT = _lib.SSL_ST_INIT
#     119 SSL_ST_BEFORE = _lib.SSL_ST_BEFORE
#     120 SSL_ST_OK = _lib.SSL_ST_OK
#
# AttributeError: module 'lib' has no attribute 'SSL_ST_INIT'
